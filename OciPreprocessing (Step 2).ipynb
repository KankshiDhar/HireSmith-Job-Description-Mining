# %%
import pandas as pd
import os
import nltk

# %%
df1=pd.read_csv(r'C:\Users\krish\Desktop\UMD\Capstone\Dataset\OCI_2018-2020.csv', encoding = 'utf_8')

# %%
df2=pd.read_csv(r'C:\Users\krish\Desktop\UMD\Capstone\Dataset\OCI_Jobs_2014-2017.csv', encoding = 'utf_8')

# %%
merged_oci=df1.append(df2)

# %%
merged_oci = merged_oci.drop(['# of Applicants',
 '# of Employees',
 '# of Extended Interview',
 '# of Interview Rooms Requested',
 '# of Not Selected',
 '# of Reserved Interview Slots',
 '# of Total Interview Slots',
 '12Twenty ID',
 'Application Deadline',
 'Approved Date',
 'Industry Duplicate',
 'Interview Room',
 'Job Function',
 'Job Posting Submit Date',
 'Job Status',
 'Job Title Duplicate',
 'Location Type',
 'Metro Area',
 'OCI Contact Address',
 'OCI Contact Title',
 'Preferred Years of Experience',
 'Source of Job Posting',
 'State',
 'US Work Auth Requirement',
 'Visit Is Cancelled'], axis = 1)

# %%
#Merging Pr_OCI & merged_oci on Job Title and Interview Dates
df3 = pd.read_csv(r'C:\Users\krish\Desktop\UMD\Capstone\pr_oci.csv', sep=',')
df3.head()
# Out:
#          Date  Job Number Cancelled  Room Reservation Test or OCS Event Type  \
# 0  10/21/2014   2139663.0       Yes                 0         OCI        OCI
# 1   2/25/2015   2139663.0        No                 0         OCI        OCI
# 2  10/21/2014   2143447.0        No                 0         OCI        OCI
# 3    3/6/2015   2162454.0        No                 0         OCI        OCI
# 4    3/6/2015   2162455.0        No                 0         OCI        OCI
#
#     Employer Industry                  Job Type  Internship  ...  Extra 4  \
# 0  Bloomberg      NaN  Summer/Winter Internship           1  ...      NaN
# 1  Bloomberg      NaN  Summer/Winter Internship           1  ...      NaN
# 2  Bloomberg      NaN                 Full-Time           0  ...      NaN
# 3  Bloomberg      NaN  Summer/Winter Internship           1  ...      NaN
# 4  Bloomberg      NaN  Summer/Winter Internship           1  ...      NaN
#
# ...

# %%
#Creating a key to merge on InterviewDate + Job Title for pr_oci
df3['key1'] = df3["Date"] + df3["Job Title"] + df3["Employer"]

# %%
#Creating a key to merge on InterviewDate + Job Title + Company Name for oci_final
merged_oci['key1'] = merged_oci["Interview Date"] + merged_oci["Job Title"] + merged_oci["Company Name"]

# %%
#rev = df1.merge(df2,on=['key1'],how='outer') , 
oci = pd.merge(merged_oci , df3[['key1','UG Opps', 'MS Opps', 'MBA Opps']], on = 'key1', how ='left')
oci.head()
# Out:
#                     Company Name  \
# 0  Exponential Interactive, Inc.
# 1  Exponential Interactive, Inc.
# 2       Alertus Technologies LLC
# 3                             EY
# 4                             EY
#
#                                             Industry Interview Date  \
# 0  Accounting, Advertising - Advertising / Market...      3/27/2020
# 1  Advertising - Advertising / Marketing Services...      3/27/2020
# 2  Tech - Equipment / Hardware / Networking, Tech...      3/11/2020
# 3                                         Accounting      3/24/2020
# 4                                         Accounting      3/24/2020
#
#                                      Job Description  \
# 0  The Performance Strategy Analyst (PSA) will ma...
# 1  Publisher Development ManagerThe Publisher Dev...
# 2  Sales Development RepresentativeWe are looking...
# 3  Assurance – Audit Internship 2021 To be consid...
# 4  Tax – Diversified Staff Group – Internship 202...
#
# ...

# %%
#Drop rows
#oci = oci.drop('Unnamed: 0',axis = 1)

# %%
len(oci)
# Out:
# 2280

# %%
print(oci.isnull().sum())
# Out:
# Company Name          0
# Industry           1493
# Interview Date        0
# Job Description     298
# Job Title             0
# Student Groups       80
# Type of Job        1494
# key1                  0
# UG Opps            1459
# MS Opps            1459
# MBA Opps           1459
# dtype: int64

# %%
oci = oci[oci['Job Description'].notna()]

# %%
oci = oci[oci['Interview Date'].notna()]

# %%
oci['Industry']=oci['Industry'].fillna("Other")

# %%
oci = oci.reset_index(drop =True)

# %%
#Splitting the data on the basis of month, year and day
mt=[]
dy=[]
year=[]
for i in range(len(oci)):
    date=oci.loc[i,'Interview Date'].split('/')
    date1=date[2].split(' ')
    mt.append(date[0])
    dy.append(date[1])
    year.append(date1[0])
        
oci['month']=mt
oci['day']=dy
oci['year']=year

# %%
oci=oci.sort_values('year')

# %%
oci = oci.reset_index(drop = True)

# %%
oci.head()
# Out:
#   Company Name Industry  Interview Date  \
# 0    MBA Focus    Other   1/1/2009 0:00
# 1     KPMG LLP    Other  10/1/2014 0:00
# 2     KPMG LLP    Other  10/1/2014 0:00
# 3     KPMG LLP    Other  10/1/2014 0:00
# 4     KPMG LLP    Other  10/1/2014 0:00
#
#                                      Job Description  \
# 0                 TEST - DO NOT APPLY; DO NOT DELETE
# 1  \rTo view this job description, please click o...
# 2  \rTo view this job description, please click o...
# 3  \rTo view this job description, please click o...
# 4   \rTo view this job description, please click ...
#
#                                            Job Title  \
# 0                 TEST - DO NOT APPLY; DO NOT DELETE
# 1  Audit Intern (Summer 2015)-Short Hills, NJ (57...
# 2      Audit Intern (Summer 2015)-Baltimore (5563BR)
# 3  Audit Intern (Summer 2015)-New York City (5618BR)
# 4  Audit Intern (Summer 2015)-Federal Practice-DC...
#
#                                       Student Groups Type of Job  \
# ...

# %%
#####################  Industry  ##################################

# %%
#### Splitting multiple industries into rows
ind = []
result = pd.DataFrame()
for i in range(len(oci)):
        ind = oci.loc[i,'Industry'].split(',')
        if len(ind) > 1:
            for j in range(len(ind)):
                result = result.append(oci.loc[[i]].assign(Industry = ind[j]), ignore_index=True)
        else:
            result = result.append(oci.loc[[i]], ignore_index=True)
# Out:
# 1201
# 1202
# 1203
# 1204
# 1205
# 1207
# 1208
# 1209
# 1213
# 1214
# 1215
# 1221
# 1227
# 1228
# 1229
# 1230
# 1239
# 1240
# 1241
# 1243
# 1244
# 1250
# 1256
# 1259
# 1263
# 1264
# 1265
# 1266
# 1267
# 1275
# 1278
# 1285
# 1291
# 1292
# 1295
# 1299
# 1300
# 1303
# 1304
# 1311
# 1313
# 1314
# 1315
# 1323
# 1324
# 1327
# 1328
# 1331
# 1332
# 1347
# 1357
# 1358
# 1362
# 1363
# 1368
# 1372
# 1373
# 1376
# 1395
# 1402
# 1407
# 1408
# 1409
# 1410
# 1416
# 1417
# 1466
# 1467
# 1470
# 1471
# 1473
# 1475
# 1478
# 1490
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1515
# 1516
# 1517
# 1518
# 1519
# 1521
# 1522
# 1523
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1534
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1546
# 1547
# 1555
# 1556
# 1562
# 1570
# 1571
# 1585
# 1586
# 1587
# 1590
# 1592
# 1596
# 1598
# 1602
# 1611
# 1613
# 1619
# 1624
# 1635
# 1638
# 1639
# 1640
# 1644
# 1645
# 1646
# 1647
# 1648
# ...

# %%
result = result.reset_index(drop = True)

# %%
len(result)
# Out:
# 2983

# %%
result['Industry'] = result['Industry'].str.strip()

# %%
result['Industry'].unique()
# Out:
# array(['Other', 'Financial - Investment Management',
#        'Financial - Commercial Banking', 'Accounting',
#        'Consulting - Technology', 'Consulting - General',
#        'Financial - General', 'Financial - Other',
#        'Advertising - Advertising / Marketing Services',
#        'Consulting - Other', 'Human Resources / Recruitment',
#        'Healthcare - Providers & Services', 'Healthcare - Biotechnology',
#        'Pharmaceutical - General', 'Pharmaceutical - Manufacturers',
#        'Healthcare - Other', 'Consulting - Healthcare', 'Financial - Tax',
#        'Consulting - Strategic / Management',
#        'Government - Local / State / Federal',
#        'Consulting - Human Capital', 'Real Estate - Commercial',
#        'Financial - Diversified Financial Services',
#        'Financial - Insurance',
#        'Financial - Investment Banking / Brokerage',
#        'Financial - Treasury', 'Consulting - Marketing',
#        'Transportation & Logistics - General',
# ...

# %%
# group some of the categories together.

msk = result['Industry'].isin(['Professional Services - Other', 
                               'Law / Legal Services',
                               'Human Resources / Recruitment',
                               'Environmental Services & Sustainability',
                               'Engineering Services',
                               'Advertising - Advertising / Marketing Services',
                               'Advertising - Communications / Public Relations',
                               'Advertising - Other',
                               'Advertising',
                               'Advertising - Advertising / Marketing Services',
                               'Advertising - Communications / Public Relations',
                               'Advertising - General',
                               'Advertising - Other'])
result.loc[msk, 'Industry'] = 'Professional Services'

msk = result['Industry'].isin(['Consulting - Biotechnology',
                               'Consulting',
                               'Consulting - Management', 
                               'Consulting - Strategy',
                               'Consulting - Design',
                               'Consulting - Gas and Oil',
                               'Consulting - General',
                               'Consulting - Healthcare',
                               'Consulting - Human Capital',
                               'Consulting - Marketing',
                               'Consulting - Nonprofit',
                               'Consulting - Other',
                               'Consulting - Strategic / Management',
                               'Consulting - Supply Chain',
                               'Consulting - Technology'])
result.loc[msk, 'Industry'] = 'Consulting'

msk = result['Industry'].isin(['Consumer Products - Apparel / Textiles',
                               'Consumer Products',
                               'Consumer Products - Beverages / Food',
                               'Consumer Products - Electronics',
                               'Consumer Products - General',
                               'Consumer Products - Household / Personal',
                               'Consumer Products - Luxury Goods',
                               'Consumer Products - Other',
                               'Consumer Products - Tobacco / Alcohol',
                               'Consumer Products - Tobacco / Alcohol'])
result.loc[msk, 'Industry'] = 'Consumer Packaged Goods'

msk = result['Industry'].isin(['Economic Development / Microfinance', 
                               'Education','Nonprofits & Social Enterprises'])
result.loc[msk, 'Industry'] = 'Government & Non Profit & Education'

msk = result['Industry'].isin(['Energy - Alternative Energy',
                               'Energy / Utilities',
                               'Energy / Utilities - Cleantech',
                               'Energy / Utilities - Energy Trading',
                               'Energy / Utilities - Oil / Gas',
                               'Energy / Utilities - Utility Services (Electric/ Water/ etc.)',
                               'Energy / Utilities - Other',
                               'Energy / Utilities - Alternative Energy',
                               'Energy - Cleantech',
                               'Energy - Energy Trading',
                               'Energy - General',
                               'Energy - Oil & Gas',
                               'Energy - Other',
                               'Energy - Utility Services (Electric / Water / etc.)'])
result.loc[msk, 'Industry'] = 'Energy'

msk = result['Industry'].isin(['Entertainment - General',
                               'Entertainment - Leisure / Recreation',
                               'Entertainment - New Media',
                               'Entertainment - Other',
                               'Entertainment',
                               'Entertainment - Sports & Sports Management'])
result.loc[msk, 'Industry'] = 'Media & Entertainment & Sports'

msk = result['Industry'].isin(['Financial - Commercial Banking',
                               'Financial - Diversified Financial Services',
                               'Financial - General',
                               'Financial - Hedge Funds',
                               'Financial - Insurance',
                               'Financial - Investment Banking / Brokerage',
                               'Financial - Investment Management',
                               'Financial - Other',
                               'Financial - Private Equity',
                               'Financial - Public Finance',
                               'Financial - Research & Ratings',
                               'Financial - Tax',
                               'Financial',
                               'Accounting',
                               'Financial - Treasury',
                               'Financial - Venture Capital'])
result.loc[msk, 'Industry'] = 'Financial Services'

msk = result['Industry'].isin(['International Trade - Import / Export',
                               'General',
                               'Natural Resources - Forest & Paper Products', 
                               'Natural Resources - General',
                               'Natural Resources - Metals / Mining',
                               'Natural Resources',
                               'Natural Resources - Other',
                               'Undefined',
                               'Aerospace / Aviation / Defense', 
                               'Agribusiness', 
                               'Automotive',
                               'Approved',
                               'Other'])
result.loc[msk, 'Industry'] = 'Other'

msk = result['Industry'].isin(['Government - General',
                               'Government - Local / State / Federal',
                               'Government - Military',
                               'Government - Other',
                               'Government',
                               'Nonprofits & Social Enterprises',
                               'Government & Non Profit & Education - General'])
result.loc[msk, 'Industry'] = 'Government & Non Profit & Education'

msk = result['Industry'].isin(['Healthcare - Biotechnology',
                               'Healthcare',
                               'Healthcare & Pharmaceuticals', 
                               'Healthcare - General',
                               'Healthcare - Medical Devices',
                               'Healthcare - Other',
                               'Healthcare - Providers & Services',
                               'Pharmaceutical',
                               'Pharmaceutical - Distribution / Wholesale',
                               'Pharmaceutical - General',
                               'Pharmaceutical - Manufacturers',
                               'Pharmaceutical - Other'])
result.loc[msk, 'Industry'] = 'Healthcare & Pharmaceuticals'

msk = result['Industry'].isin(['Hospitality - General',
                               'Hospitality / Tourism',
                               'Hospitality - Lodging',
                               'Hospitality - Tourism',
                               'Hospitality - Transportation'])
result.loc[msk, 'Industry'] = 'Hospitality'

msk = result['Industry'].isin(['Manufacturing - Chemicals',
                               'Manufacturing',
                               'Manufacturing - General',
                               'Manufacturing - Heavy Equipment',
                               'Manufacturing - Other',
                               'Manufacturing - Packaging',
                               'Manufacturing - Plastics / Rubber'])
result.loc[msk, 'Industry'] = 'Manufacturing'

msk = result['Industry'].isin(['Media - General',
                               'Media',
                               'Media - Other',
                               'Media - Publishing (Print / Web)',
                               'Media - Radio / TV / Cable / Film',
                               'Media & Entertainment & Sports - Other'])
result.loc[msk, 'Industry'] = 'Media & Entertainment & Sports'

msk = result['Industry'].isin(['Real Estate - Commercial',
                               'Real Estate', 
                               'Construction',
                               'Real Estate - General',
                               'Real Estate - Other',
                               'Real Estate - Residential',
                               'Real Estate - Services'])
result.loc[msk, 'Industry'] = 'Real Estate & Construction'

msk = result['Industry'].isin(['Retail - General', 'Retail']) 
result.loc[msk, 'Industry'] = 'Retail'

msk = result['Industry'].isin(['Tech - Equipment / Hardware / Networking',
                               'Tech - General',
                               'Technology',
                               'Technology - Equipment / Hardware / Networking',
                               'Technology - Software', 
                               'Technology - Other', 
                               'Telecom',
                               'Technology - Other',
                               'Technology - Internet Services / E-Commerce',
                               'Tech - Internet Services / E-Commerce',
                               'Technology - Multimedia Products & Services',
                               'Technology - Internet Services / E-Commerce',
                               'Tech - Multimedia Products & Services',
                               'Tech - Other',
                               'Tech - Software',
                               'Telecom - General',
                               'Telecom - Manufacturing',
                               'Telecom - Other',
                               'Telecom - Services'])
result.loc[msk, 'Industry'] = 'Technology'

msk = result['Industry'].isin(['Transportation & Logistics - 3PL',
                               'Transportation',
                               'Transportation & Logistics', 
                               'Transportation - 3PL', 
                               'Logistics',
                               'Transportation - Motor Carrier', 
                               'Transportation - Railroad',
                               'Transportation - Supply Chain',
                               'Transportation - Marine (Ocean and Port Authorities)',
                               'Transportation & Logistics - General',
                               'Transportation & Logistics - Marine (Ocean and Port Authorities)',
                               'Transportation & Logistics - Motor Carrier',
                               'Transportation & Logistics - Railroad',
                               'Transportation & Logistics - Supply Chain'])
result.loc[msk, 'Industry'] = 'Transportation & Logistics'

# %%
result['Industry'].unique()
# Out:
# array(['Other', 'Financial Services', 'Consulting',
#        'Professional Services', 'Healthcare & Pharmaceuticals',
#        'Government & Non Profit & Education',
#        'Real Estate & Construction', 'Transportation & Logistics',
#        'Manufacturing', 'Retail', 'Hospitality',
#        'Consumer Packaged Goods', 'Media & Entertainment & Sports',
#        'Technology', 'Energy'], dtype=object)

# %%
result.drop_duplicates(inplace = True)

# %%
result=result.sort_values('year')

# %%
result.tail()
# Out:
#                        Company Name                    Industry  \
# 2668             Grant Thornton LLP          Financial Services
# 2669                       Deloitte          Financial Services
# 2670                       Deloitte          Financial Services
# 2661                             EY          Financial Services
# 2960  Exponential Interactive, Inc.  Transportation & Logistics
#
#      Interview Date                                    Job Description  \
# 2668       3/9/2020  Please apply to the position/location you are ...
# 2669      3/10/2020  **HOW TO APPLY**Please read this section in it...
# 2670      3/10/2020  Deloitte Risk & Financial Advisory Intern – Go...
# 2661      3/24/2020  Assurance – Audit Internship 2021 To be consid...
# 2960      3/27/2020  The Performance Strategy Analyst (PSA) will ma...
#
#                                               Job Title  \
# 2668  Tax Intern - Winter 2021- Summer Leadership Pr...
# ...

# %%
result.to_csv("CategorizedOCI.csv")

# %%
############################################
