# %%
import pandas as pd
import os
import nltk

# %%
## Set your working Directory ##
## os.chdir('C:/Users/krish/Desktop/UMD/Capstone')

# %%
df1=pd.read_csv(r'C:\Users\krish\Desktop\UMD\Capstone\Dataset\JobListings_2018-2020.csv', encoding = 'utf_8')

# %%
df2=pd.read_csv(r'C:\Users\krish\Desktop\UMD\Capstone\Dataset\Joblistings_2014-2017.csv', encoding = 'utf_8')

# %%
jl = pd.DataFrame()
jl=df1.append(df2)

# %%
jl=jl.drop(['Industry Duplicate', 
         'Job Contact Address Line 1',
         'Job Contact Address Line 2',
         'Job Contact Address Line 3',
         '# of Applicants',
         '12TwentyGPS Network Jobs',
         'Additional Application Document Description',
         'Additional Application Document Required',
         'Application Deadline',
         'Application Web Site',
         'Application email address',
         'Approved Date',
         'Area of Study',
         'Country',
         'City',
         'State',
         'Job # Applicants',
         'Job # Matches',
         'Job # Views',
         'Job Application Method',
         'Job Contact City',
         'Job Title Duplicate',
         'Job Contact Fax #',
         'Job Contact Name',
         'Job Contact Name (Pre-Merge)',
         'Job Contact Phone Number',
         'Job Contact Postal Code',
         'Job Contact Title',
         'Job Contact email address',
        'Job Expiration Date',
         'Job Is Converted From Visit',
         'Job Is Converted To Visit',
         'Job Is Multipost',
         'Job Posting - Updated By',
         'Job Posting - Updated Date',
         'Job Posting Cover Letter',
        'Content Entity - Channels',
        'Class Year',
         'Delivery Of Job Posting Applications',
         'First Name',
         'Job Requisition Number',
         'Job Start Date',
         'Keyword(s)',
         'Last Name',
         'Location Type',
         'Organization Description',
         'Organization Name (Pre-Merge)',
         'Overall GPA',
         'Preferred Years of Experience',
         'Program',
         'Screening Categories',
         'Search Firm Name',
         'Source of Job Posting',
         'Transcripts Required?',
         'What type of additional document?',
         'Work Authorization',
         'Work Eligibility for Screening'], axis = 1)

# %%
len(jl)
# Out:
# 29255

# %%
print(jl.isnull().sum())
# Out:
# Company Name                  75
# Industry                    2856
# Job Description               90
# Job Function                6609
# Job Posting Date             104
# Job Status                    84
# Job Title                     73
# Job Type                    4378
# Location                    2978
# Student Groups              5385
# US Work Auth Requirement    6037
# Unique ID                     73
# dtype: int64

# %%
jl = jl[jl['Job Description'].notna()]

# %%
jl = jl[jl['Job Posting Date'].notna()]

# %%
jl['Industry']=jl['Industry'].fillna("Other")

# %%
jl['Job Function']=jl['Job Function'].fillna("Other")

# %%
jl = jl.reset_index(drop =True)

# %%
#Splitting the data on the basis of month, year and day
mt=[]
dy=[]
year=[]
for i in range(len(jl)):
    date=jl.loc[i,'Job Posting Date'].split('/')
    date1=date[2].split(' ')
    mt.append(date[0])
    dy.append(date[1])
    year.append(date1[0])
        
jl['month']=mt
jl['day']=dy
jl['year']=year

# %%
jl=jl.sort_values('year')

# %%
jl = jl.reset_index(drop = True)

# %%
jl=jl.rename({'Job Function':'Job_Function'},axis=1)

# %%
jl.head()
# Out:
#            Company Name                                    Industry  \
# 0          BDO USA, LLP                                       Other
# 1    The Boeing Company              Aerospace / Aviation / Defense
# 2    The Boeing Company              Aerospace / Aviation / Defense
# 3  New Capital Partners                  Financial - Private Equity
# 4         Deutsche Bank  Financial - Investment Banking / Brokerage
#
#                                      Job Description  \
# 0  BDO’s summer leadership program, Pathway to Su...
# 1  Boeing is developing a professional services c...
# 2  Boeing is developing a professional services c...
# 3  NCP is seeking candidates who possess an excel...
# 4                                         The pos...
#
#                                         Job_Function  Job Posting Date  \
# 0                                              Other    2/16/2011 0:00
# 1  Technology, Technology - Business Analysis and...  10/27/2011 15:10
# ...

# %%
#####################  Industry  ##################################

# %%
#### Splitting multiple industries into rows
ind = []
result = pd.DataFrame()
for i in range(len(jl)):
        ind = jl.loc[i,'Industry'].split(',')
        if len(ind) > 1:
            for j in range(len(ind)):
                result = result.append(jl.loc[[i]].assign(Industry = ind[j]), ignore_index=True)
        else:
            result = result.append(jl.loc[[i]], ignore_index=True)

# %%
result = result.reset_index(drop = True)

# %%
len(result)
# Out:
# 60580

# %%
result['Industry'] = result['Industry'].str.strip()

# %%
result['Industry'].unique()
# Out:
# array(['Other', 'Aerospace / Aviation / Defense',
#        'Financial - Private Equity',
#        'Financial - Investment Banking / Brokerage', 'Consulting - Other',
#        'Accounting', 'Financial - Investment Management',
#        'Technology - Multimedia Products & Services',
#        'Technology - Internet Services / E-Commerce',
#        'Natural Resources - Metals / Mining',
#        'Consumer Products - Electronics',
#        'Financial - Diversified Financial Services',
#        'Consulting - Strategy', 'Technology - Software',
#        'Consulting - Nonprofit', 'Retail', 'Financial - Insurance',
#        'Consumer Products - Other', 'Consulting - Technology',
#        'Energy / Utilities - Utility Services (Electric/ Water/ etc.)',
#        'Technology - Other', 'Consumer Products - Luxury Goods',
#        'Entertainment', 'Economic Development / Microfinance',
#        'Consulting - Healthcare', 'Law / Legal Services',
# ...

# %%
# group some of the categories together.

msk = result['Industry'].isin(['Professional Services - Other', 
                               'Law / Legal Services',
                               'Human Resources / Recruitment',
                               'Environmental Services & Sustainability',
                               'Engineering Services',
                               'Advertising - Advertising / Marketing Services',
                               'Advertising - Communications / Public Relations',
                               'Advertising - Other',
                               'Advertising',
                               'Advertising - Advertising / Marketing Services',
                               'Advertising - Communications / Public Relations',
                               'Advertising - General',
                               'Advertising - Other'])
result.loc[msk, 'Industry'] = 'Professional Services'

msk = result['Industry'].isin(['Consulting - Biotechnology',
                               'Consulting',
                               'Consulting - Management', 
                               'Consulting - Strategy',
                               'Consulting - Design',
                               'Consulting - Gas and Oil',
                               'Consulting - General',
                               'Consulting - Healthcare',
                               'Consulting - Human Capital',
                               'Consulting - Marketing',
                               'Consulting - Nonprofit',
                               'Consulting - Other',
                               'Consulting - Strategic / Management',
                               'Consulting - Supply Chain',
                               'Consulting - Technology'])
result.loc[msk, 'Industry'] = 'Consulting'

msk = result['Industry'].isin(['Consumer Products - Apparel / Textiles',
                               'Consumer Products',
                               'Consumer Products - Beverages / Food',
                               'Consumer Products - Electronics',
                               'Consumer Products - General',
                               'Consumer Products - Household / Personal',
                               'Consumer Products - Luxury Goods',
                               'Consumer Products - Other',
                               'Consumer Products - Tobacco / Alcohol',
                               'Consumer Products - Tobacco / Alcohol'])
result.loc[msk, 'Industry'] = 'Consumer Packaged Goods'

msk = result['Industry'].isin(['Economic Development / Microfinance', 
                               'Education','Nonprofits & Social Enterprises'])
result.loc[msk, 'Industry'] = 'Government & Non Profit & Education'

msk = result['Industry'].isin(['Energy - Alternative Energy',
                               'Energy / Utilities',
                               'Energy / Utilities - Cleantech',
                               'Energy / Utilities - Energy Trading',
                               'Energy / Utilities - Oil / Gas',
                               'Energy / Utilities - Utility Services (Electric/ Water/ etc.)',
                               'Energy / Utilities - Other',
                               'Energy / Utilities - Alternative Energy',
                               'Energy - Cleantech',
                               'Energy - Energy Trading',
                               'Energy - General',
                               'Energy - Oil & Gas',
                               'Energy - Other',
                               'Energy - Utility Services (Electric / Water / etc.)'])
result.loc[msk, 'Industry'] = 'Energy'

msk = result['Industry'].isin(['Entertainment - General',
                               'Entertainment - Leisure / Recreation',
                               'Entertainment - New Media',
                               'Entertainment - Other',
                               'Entertainment',
                               'Entertainment - Sports & Sports Management'])
result.loc[msk, 'Industry'] = 'Media & Entertainment & Sports'

msk = result['Industry'].isin(['Financial - Commercial Banking',
                               'Financial - Diversified Financial Services',
                               'Financial - General',
                               'Financial - Hedge Funds',
                               'Financial - Insurance',
                               'Financial - Investment Banking / Brokerage',
                               'Financial - Investment Management',
                               'Financial - Other',
                               'Financial - Private Equity',
                               'Financial - Public Finance',
                               'Financial - Research & Ratings',
                               'Financial - Tax',
                               'Financial',
                               'Accounting',
                               'Financial - Treasury',
                               'Financial - Venture Capital'])
result.loc[msk, 'Industry'] = 'Financial Services'

msk = result['Industry'].isin(['International Trade - Import / Export',
                               'General',
                               'Natural Resources - Forest & Paper Products', 
                               'Natural Resources - General',
                               'Natural Resources - Metals / Mining',
                               'Natural Resources',
                               'Natural Resources - Other',
                               'Undefined',
                               'Aerospace / Aviation / Defense', 
                               'Agribusiness', 
                               'Automotive',
                               'Approved',
                               'Other'])
result.loc[msk, 'Industry'] = 'Other'

msk = result['Industry'].isin(['Government - General',
                               'Government - Local / State / Federal',
                               'Government - Military',
                               'Government - Other',
                               'Government',
                               'Nonprofits & Social Enterprises',
                               'Government & Non Profit & Education - General'])
result.loc[msk, 'Industry'] = 'Government & Non Profit & Education'

msk = result['Industry'].isin(['Healthcare - Biotechnology',
                               'Healthcare',
                               'Healthcare & Pharmaceuticals', 
                               'Healthcare - General',
                               'Healthcare - Medical Devices',
                               'Healthcare - Other',
                               'Healthcare - Providers & Services',
                               'Pharmaceutical',
                               'Pharmaceutical - Distribution / Wholesale',
                               'Pharmaceutical - General',
                               'Pharmaceutical - Manufacturers',
                               'Pharmaceutical - Other'])
result.loc[msk, 'Industry'] = 'Healthcare & Pharmaceuticals'

msk = result['Industry'].isin(['Hospitality - General',
                               'Hospitality / Tourism',
                               'Hospitality - Lodging',
                               'Hospitality - Tourism',
                               'Hospitality - Transportation'])
result.loc[msk, 'Industry'] = 'Hospitality'

msk = result['Industry'].isin(['Manufacturing - Chemicals',
                               'Manufacturing',
                               'Manufacturing - General',
                               'Manufacturing - Heavy Equipment',
                               'Manufacturing - Other',
                               'Manufacturing - Packaging',
                               'Manufacturing - Plastics / Rubber'])
result.loc[msk, 'Industry'] = 'Manufacturing'

msk = result['Industry'].isin(['Media - General',
                               'Media',
                               'Media - Other',
                               'Media - Publishing (Print / Web)',
                               'Media - Radio / TV / Cable / Film',
                               'Media & Entertainment & Sports - Other'])
result.loc[msk, 'Industry'] = 'Media & Entertainment & Sports'

msk = result['Industry'].isin(['Real Estate - Commercial',
                               'Real Estate', 
                               'Construction',
                               'Real Estate - General',
                               'Real Estate - Other',
                               'Real Estate - Residential',
                               'Real Estate - Services'])
result.loc[msk, 'Industry'] = 'Real Estate & Construction'

msk = result['Industry'].isin(['Retail - General', 'Retail']) 
result.loc[msk, 'Industry'] = 'Retail'

msk = result['Industry'].isin(['Tech - Equipment / Hardware / Networking',
                               'Tech - General',
                               'Technology',
                               'Technology - Equipment / Hardware / Networking',
                               'Technology - Software', 
                               'Technology - Other', 
                               'Telecom',
                               'Technology - Other',
                               'Technology - Internet Services / E-Commerce',
                               'Tech - Internet Services / E-Commerce',
                               'Technology - Multimedia Products & Services',
                               'Technology - Internet Services / E-Commerce',
                               'Tech - Multimedia Products & Services',
                               'Tech - Other',
                               'Tech - Software',
                               'Telecom - General',
                               'Telecom - Manufacturing',
                               'Telecom - Other',
                               'Telecom - Services'])
result.loc[msk, 'Industry'] = 'Technology'

msk = result['Industry'].isin(['Transportation & Logistics - 3PL',
                               'Transportation',
                               'Transportation & Logistics', 
                               'Transportation - 3PL', 
                               'Logistics',
                               'Transportation - Motor Carrier', 
                               'Transportation - Railroad',
                               'Transportation - Supply Chain',
                               'Transportation - Marine (Ocean and Port Authorities)',
                               'Transportation & Logistics - General',
                               'Transportation & Logistics - Marine (Ocean and Port Authorities)',
                               'Transportation & Logistics - Motor Carrier',
                               'Transportation & Logistics - Railroad',
                               'Transportation & Logistics - Supply Chain'])
result.loc[msk, 'Industry'] = 'Transportation & Logistics'

# %%
result['Industry'].unique()
# Out:
# array(['Other', 'Financial Services', 'Consulting', 'Technology',
#        'Consumer Packaged Goods', 'Retail', 'Energy',
#        'Media & Entertainment & Sports',
#        'Government & Non Profit & Education', 'Professional Services',
#        'Healthcare & Pharmaceuticals', 'Manufacturing',
#        'Transportation & Logistics', 'Hospitality',
#        'Real Estate & Construction'], dtype=object)

# %%
result.drop_duplicates(inplace = True)

# %%
result=result.sort_values('year')

# %%
result.head()
# Out:
#                            Company Name                        Industry  \
# 0                          BDO USA, LLP                           Other
# 322                          Amazon.com         Consumer Packaged Goods
# 321                          Amazon.com  Media & Entertainment & Sports
# 320  SAMSUNG TELECOMMUNICATIONS AMERICA                      Technology
# 319           Toyota Financial Services              Financial Services
#
#                                        Job Description  \
# 0    BDO’s summer leadership program, Pathway to Su...
# 322  In this role you will:\r Define the growth str...
# 321  Basic Qualifications:Bachelor’s degree Minimum...
# 320      \rPosition Description: We are looking for...
# 319  \r Toyota Financial Services \r  \rOur people ...
#
#                                           Job_Function Job Posting Date  \
# 0                                                Other   2/16/2011 0:00
# ...

# %%
result.to_csv("jlByIndustry.csv")

# %%
########################### Job Function ###############################################

# %%
#### Splitting multiple industries into rows
ind = []
result = pd.DataFrame()
for i in range(len(jl)):
        ind = jl.loc[i,'Job_Function'].split(',')
        if len(ind) > 1:
            for j in range(len(ind)):
                result = result.append(jl.loc[[i]].assign((Job_Function) = ind[j]), ignore_index=True)
        else:
            result = result.append(jl.loc[[i]], ignore_index=True)

# %%
result = result.reset_index(drop = True)

# %%
len(result)
# Out:
# 152945

# %%
result['Job_Function'] = result['Job_Function'].str.strip()

# %%
result['Job_Function'].unique()
# Out:
# array(['Other', 'Technology', 'Technology - Business Analysis and Design',
#        'Technology - Ecommerce / Internet / Web Site Mgmt',
#        'Technology - Integration / Implementation',
#        'Technology - Systems Management',
#        'Technology - Training and Development', 'Technology - Other',
#        'Entrepreneurship', 'Finance - Other',
#        'Finance - Corporate Finance', 'Finance - Investment Banking',
#        'Finance - Investment Management', 'Finance - Risk Management',
#        'Finance - Treasury', 'Consulting', 'Accounting',
#        'Accounting - Audit', 'Accounting - Tax', 'Accounting - Advisory',
#        'Accounting - Other', 'Finance', 'Finance - Analyst / Research',
#        'Finance - Commercial Banking',
#        'Finance - Lending / Relationship Mgmt',
#        'Finance - Mergers & Acquisitions',
#        'Finance - Private Client Services / Wealth Mgmt',
#        'Finance - Public Finance', 'Finance - Restructure / Turnaround',
# ...

# %%
# group some of the categories together.

msk = result['Job_Function'].isin(['Professional Services - Other', 'Law / Legal Services','Human Resources / Recruitment',
'Human Resources - Other','Human Resources - Generalist','Human Resources','Human Resources - Recruiter / Exec. Search',
'Environmental Services & Sustainability','Human Resources - Executive Coaching','Legislative Aide / Lobbying / Advocate',
'Advertising - Advertising / Marketing Services', 'Advertising - Communications / Public Relations','Advertising - Other',
'Lawyer / Legal Professional', 'Advertising','Marketing - Advertising', 'Advertising - Advertising / Marketing Services',
'Advertising - Communications / Public Relations', 'Advertising - General','Advertising - Other'])
result.loc[msk, 'Job_Function'] = 'Professional Services'


msk = result['Job_Function'].isin(['Marketing - Brand / Product Management', 'Business Development', 'Corporate Development',
'Marketing - Product Development/Innovation','Management - International / Multinational','Management - Operations / Production',
'Marketing - Merchandising / Retail', 'Marketing - Other','Management - Project Mgmt.', 'Economic Analysis / Research',
'Research & Development','Management - Rotational / Development Program','Management - Supply Chain / Logistics','Sales',  
'Marketing','General Management','Marketing - Communications / Public Relations','Management - Customer Relations', 
'Management - General Manager','Management', 'Marketing|Sales - Marketing-Other Services', 'Other - Analytics',
'Marketing Analytics - Market Research','Marketing Analytics - Other Services','Marketing Analytics - Business Analytics',
'Marketing Analytics - Consumer Insights','Marketing Analytics - Consumer Segmentation','Marketing Analytics - Data Analytics/Big Data',
'Marketing Analytics - Sales Analytics', 'Marketing Analytics - Strategy','Marketing - Market Research', 'General Business',
'Sales - Account Executive/Advertising','General Management - Project Management','General Management - Rotational Program',
'Marketing|Sales - Account Executive/Advertising','Marketing|Sales - Market Research', 'Marketing|Sales - Sales',
'Marketing|Sales - Product Management','Marketing|Sales - Merchandising/Retail Marketing','Marketing - Market Research',
'Management - Other','Buyer / Merchandising','Marketing|Sales - Brand Management','Strategic Planning',
'Marketing|Sales - Marketing Consulting','Marketing|Sales - Marketing-Financial Services','Marketing Analytics - Brand Management',
'Marketing Analytics - Financial Services','Marketing Analytics - Merchandising/Retail Marketing','Marketing Analytics - Product Management',
'Marketing Analytics - Public Relations','Marketing Analytics - Consulting'])
result.loc[msk, 'Job_Function'] = 'Marketing/Business/Sales Management'


msk = result['Job_Function'].isin(['Engineering', 'Engineering - Chemical','Engineering Services',
'Engineering - Electrical', 'Engineering - Industrial','Engineering - Mechanical', 'Engineering - Other'])
result.loc[msk, 'Job_Function'] = 'Engineering Services'


msk = result['Job_Function'].isin(['Consulting - Biotechnology','Consulting','Consulting - Internal','Consulting - External',
'Consulting - Management', 'Consulting - Strategy','Consulting - Design','Consulting - Gas and Oil','Consulting - General',
'Consulting - Healthcare','Consulting - Human Capital','Consulting - Marketing','Consulting - Nonprofit','Consulting - Other',
'Consulting - Strategic / Management','Consulting - Supply Chain','Consulting - Technology'])
result.loc[msk, 'Job_Function'] = 'Consulting'

msk = result['Job_Function'].isin(['Consumer Products - Apparel / Textiles','Consumer Products','Consumer Products - Beverages / Food',
'Consumer Products - Electronics','Consumer Products - General','Consumer Products - Household / Personal',
'Consumer Products - Luxury Goods','Consumer Products - Other','Consumer Products - Tobacco / Alcohol',
'Consumer Products - Tobacco / Alcohol'])
result.loc[msk, 'Job_Function'] = 'Consumer Packaged Goods'

msk = result['Job_Function'].isin(['economic development / microfinance', 'education', 'nonprofits & social enterprises', 
                                   'government - general', 'government - local / state / federal', 'government - military',
                                   'government - other', 'government', 'other - government affairs', 
                                   'government & non profit & education - general'])
result.loc[msk, 'Job_Function'] = 'Government & Non Profit & Education'

msk = result['Job_Function'].isin(['Energy - Alternative Energy','Energy / Utilities','Energy / Utilities - Cleantech',
'Energy / Utilities - Energy Trading','Energy / Utilities - Oil / Gas','Energy / Utilities - Utility Services (Electric/ Water/ etc.)',
'Energy / Utilities - Other','Energy / Utilities - Alternative Energy','Energy - Cleantech','Energy - Energy Trading',
'Energy - General','Energy - Oil & Gas','Energy - Other','Energy - Utility Services (Electric / Water / etc.)'])
result.loc[msk, 'Job_Function'] = 'Energy'

msk = result['Job_Function'].isin(['entertainment - general', 'entertainment - leisure / recreation', 'entertainment',
                                   'multimedia production / graphic design', 'entertainment - new media', 
                                   'entertainment - other', 'entertainment - sports & sports management', 
                                   'media - general', 'media', 'media - other', 'media - publishing (print / web)', 
                                   'media - radio / tv / cable / film', 'media & entertainment & sports - other'])
result.loc[msk, 'Job_Function'] = 'Media & Entertainment & Sports'

msk = result['Job_Function'].isin(['Financial - Commercial Banking','Financial - Diversified Financial Services',
'Financial - General','Financial - Hedge Funds','Finance - Other', 'Finance - Corporate Finance',
'Finance - Investment Banking', 'Finance - Investment Management','Finance - Risk Management', 'Finance - Treasury',
'Financial - Insurance','Financial Services', 'Accounting - Audit', 'Accounting - Tax','Accounting - Advisory', 
'Accounting - Other', 'Finance','Finance - Analyst / Research', 'Finance - Commercial Banking',
'Finance - Lending / Relationship Mgmt','Finance - Mergers & Acquisitions','Finance|Accounting - Commercial Banking/Lending',
'Finance - Private Client Services / Wealth Mgmt','Finance - Public Finance', 'Finance - Restructure / Turnaround',
'Finance - Sales & Trading','Finance - Private Equity','Financial - Investment Banking / Brokerage',
'Financial - Investment Management','Financial - Other','Finance|Accounting - Accounting/Auditing','Accounting - Audit/Assurance', 'Marketing|Sales - Public Relations',
'Finance - Real Estate Finance','Finance - Commercial Banking/Lending','Finance - Corporation Finance/Financial Analysis/FP&A',
'Finance - Corporation Finance/Treasury','Finance - Private Wealth Management','Finance - Research Analyst/Portfolio Manager',
'Finance - Sales/Trading', 'Accounting - Financial Services Audit/Assurance','Accounting - Financial Services Tax', 
'Accounting - Government','Accounting - Internal Audit/Risk Advisory','Finance|Accounting - Real Estate Finance',
'Finance|Accounting - Venture Capital/Private Equity/LBO','Finance - Venture Capital/Private Equity/LBO',
'Accounting - Financial Services Advisory', 'Accounting - General','Accounting - Forensic', 'Financial',
'Finance|Accounting - Corporation Finance/Financial Analysis/FP&A','Finance|Accounting - Corporation Finance/Treasury',
'Finance|Accounting - Investment Banking','Finance|Accounting - Investment Management','Finance|Accounting - Private Wealth Management',
'Finance|Accounting - Research Analyst/Portfolio Manager','Finance|Accounting - Sales/Trading','Accounting - IT Audit',
'Financial - Private Equity','Financial - Public Finance','Financial - Research & Ratings','Financial - Tax',
'Accounting','Financial - Treasury','Financial - Venture Capital'])
result.loc[msk, 'Job_Function'] = 'Financial Services'

msk = result['Job_Function'].isin(['International Trade - Import / Export','General', 'Natural Resources - General',
'Natural Resources - Forest & Paper Products', 'Natural Resources - Metals / Mining','Natural Resources',
'Natural Resources - Other','Undefined','Aerospace / Aviation / Defense', 'Agribusiness','Other - Strategic Planning',
'Administration', 'Other - Law','Military', 'Corporate Social Responsibility','Fundraising / Development',
'Journalist / Author / Writer / Editor','Automotive','Approved','Education (Administrator/ Faculty)','Other'])
result.loc[msk, 'Job_Function'] = 'Other'


msk = result['Job_Function'].isin(['Healthcare - Biotechnology','Healthcare', 'Health Care / Medical Professional',
'Healthcare & Pharmaceuticals', 'Healthcare - General','Healthcare - Medical Devices','Healthcare - Other',
'Healthcare - Providers & Services','Pharmaceutical','Pharmaceutical - Distribution / Wholesale','Pharmaceutical - General',
'Pharmaceutical - Manufacturers','Pharmaceutical - Other'])
result.loc[msk, 'Job_Function'] = 'Healthcare & Pharmaceuticals'

msk = result['Job_Function'].isin(['Hospitality - General','Hospitality / Tourism','Hospitality - Lodging',
'Hospitality - Tourism','Hospitality - Transportation'])

result.loc[msk, 'Job_Function'] = 'Hospitality'

msk = result['Job_Function'].isin(['Manufacturing - Chemicals','Manufacturing','Manufacturing', 'Manufacturing - Materials',
'Manufacturing - Plant / Facility Mgmt.','Manufacturing - Quality Control','Purchasing',
'Manufacturing - General','Manufacturing - Heavy Equipment','Manufacturing - Other','Manufacturing - Packaging',
'Manufacturing - Plastics / Rubber'])
result.loc[msk, 'Job_Function'] = 'Manufacturing'


msk = result['Job_Function'].isin(['Real Estate - Commercial','Real Estate','Other - Real Estate Development',
'Real Estate & Construction','Real Estate - Asset / Property Mgmt','Real Estate - Development / Construction',
'Real Estate - Finance','Construction','Real Estate - General','Real Estate - Other','Real Estate - Residential',
'Real Estate - Services'])
result.loc[msk, 'Job_Function'] = 'Real Estate & Construction'

msk = result['Job_Function'].isin(['Retail - General', 'Retail','Management - Retail Mgmt.']) 
result.loc[msk, 'Job_Function'] = 'Retail'

msk = result['Job_Function'].isin(['Tech - Equipment / Hardware / Networking','Tech - General','Technology',
'Information Systems - Coding','Information Systems - Data Analytics/Big Data','Information Systems - Programming',
'Information Systems - IT Advisory/Consulting','Technology - Equipment / Hardware / Networking','Technology - Software', 
'Technology - Other','MIS','Consulting - Information Systems/Technology', 'Telecom','Information Systems - Business Analytics',
'Technology - Other','Technology - Internet Services / E-Commerce','Tech - Internet Services / E-Commerce',
'Technology - Multimedia Products & Services','Technology - Internet Services / E-Commerce','Tech - Multimedia Products & Services',
'Technology - Business Analysis and Design','Technology - Ecommerce / Internet / Web Site Mgmt','Entrepreneurship',
'Technology - Integration / Implementation','Technology - Systems Management','Technology - Training and Development',
'Tech - Other','Analytics','Tech - Software','Telecom - General','Telecom - Manufacturing','Telecom - Other',
'Telecom - Services'])
result.loc[msk, 'Job_Function'] = 'Technology'

msk = result['Job_Function'].isin(['Transportation & Logistics - 3PL','Transportation','Transportation & Logistics', 
'Transportation - 3PL', 'Logistics','Operations - Operations Specialist','Operations - Transportation Analyst', 'Procurement',
'Transportation - Motor Carrier', 'Transportation - Railroad','Transportation - Supply Chain','Transportation - Account Manager',
'Supply Chain - Logistics', 'Supply Chain - Management','Supply Chain - Procurement', 'Supply Chain - Transportation',
'Transportation - Customer Service','Transportation - Logistics Coordinator/Agent','Transportation - Sales and Marketing',
'Operations - Warehouse Manager', 'Operations - Fleet Operations','Operations', 'Operations - Motor Carrier Operations',
'Operations - Rail Network Operations','Transportation & Logistics', 'Transportation - Business Analyst',
'Other - Business/Corporate Development', 'Sales - Sales','Supply Chain - Logistics/Operations','Supply Chain - Consulting',
'Supply Chain - Merchandising', 'Supply Chain - Operations','Supply Chain - Rotational Program', 'Supply Chain - Sourcing',
'Transportation - Marine (Ocean and Port Authorities)','Transportation & Logistics - General',
'Transportation & Logistics - Marine (Ocean and Port Authorities)','Transportation & Logistics - Motor Carrier',
'Transportation & Logistics - Railroad','Operations/Logistics/Supply Chain','Transportation & Logistics - Supply Chain'])
result.loc[msk, 'Job_Function'] = 'Transportation & Logistics'

# %%
func_list = result['Job_Function'].unique()

# %%
result.drop_duplicates(inplace = True)

# %%
 result=result.sort_values('year')

# %%
result = result.reset_index(drop =True)

# %%
result.head()
# Out:
#                        Company Name                 Industry  \
# 0                      BDO USA, LLP                    Other
# 1                McKinsey & Company       Consulting - Other
# 2        First Annapolis Consulting                    Other
# 3                    JK Group, Inc.  Consulting - Technology
# 4  EPIC Academy Charter High School                Education
#
#                                      Job Description  \
# 0  BDO’s summer leadership program, Pathway to Su...
# 1  \rSpecialists are dedicated to working with cl...
# 2  First Annapolis Consulting, Inc., offers a car...
# 3  PRIMARY RESPONSIBILITIES Manage the company’s ...
# 4  \rEPIC Academy’s early work as a startup organ...
#
#                           Job_Function Job Posting Date Job Status  \
# 0                                Other   2/16/2011 0:00   Approved
# 1  Marketing/Business/Sales Management  7/20/2011 13:10   Approved
# 2                                Other   2/22/2011 0:00   Approved
# ...

# %%
result.to_csv("jlByFunction.csv")

# %%
print(result.isnull().sum())
# Out:
# Company Name                   1
# Industry                       0
# Job Description                0
# Job_Function                   0
# Job Posting Date               0
# Job Status                     8
# Job Title                      0
# Job Type                    4294
# Location                    3364
# Student Groups              5348
# US Work Auth Requirement    6085
# Unique ID                      0
# month                          0
# day                            0
# year                           0
# dtype: int64

# %%
############################################
